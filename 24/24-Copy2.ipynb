# %%
mapp="""#.######################################################################################################################################################
#>.^v.>^v>><>>^>>v>v^>.<>^.>v^v>..<<><>>>v.><^<.>^.<^>^v^>>v<^>><.^<^.<v>v><><^^<^>>^<<<>.>.>^^^<^<^>.>^v.>.>^>^v<<^^<>><vv<><>>>v^.>^<vvv>.^>v.>.v<v.<#
#<^^^><<vv<vv^^><>><>vv.vv<>vvvv<vv.>^>^>v^vvv>.<^>v<>>.<><<><>v<v^^<^.v^^><<><^><<.v.vv<<><.<<<<v^^>><^<><^<<<<.>v<^v<v>^>>>><.v>^>.>^<^>>v<v<^vv<v>v<#
#>>>>^.>.^v>v<.^<^vv^^^<>.>>.>><<.v<v^><^><.<<<><.^v^^v<><v^v><vv<<v<..<<^<.<>^<^v.^>^<v^v.^<v>v<><>>>^v<v.^^<><>><>v<^v>>>^v<v^>v<^vvv><v>^><<><^v>>^>#
#><<>^>v>.<^^v><v.<>v^<<<>^^v>^.v<<>><>v.v>v^.v>>>^<^><.>>v<<<>vv^.>^>^<><^.>.v^^<v<.^>^><>^<v>vv^v>v^<>><<vv>>>v^^<^v>>>v.<<>.v<><^^v<.^>v>.<^^><vv.^>#
#<.v^vv^vv>><v>^>>^.vvv^^<v<.v^>><<>v<v<<^<<<vv.>><>v.^>vvv<v<v>^<>>v><.>^.>.^<<<.^vvv>^..^>>.v<v.^v^<^^<<^<^>^v>^v<vvv.v^^v<<<>^v<<<v><>v^<<^><.v>v<v>#
#<^v^><>v^<.>vv>.^<<<vv^^<><^<^.^^<.^vv^>v^^.^<^>^.^<><><^<<>><vv<v^<>v<><>v^^v<.<v^<v>vvv>^>>^<^><>>^vv<^>><v><^.<<v><v.>^v^v>>>^<vv>v<^<><>.^^>.v><<>#
#<.><^v>^<.>>v<v>v<^v^v.^>v<.v>.<vv>^>v<v<<>^^.<>.<.vvv<^>v^.^<^v>^.>.v<.v>><<<^vv^.^<<^<^v<v^^^>.><>v.^^.^><<.<vvvv<v><<^vv.<^^^^>^<.<><<>>^>v>.^^v.<<#
#<<^.>v<><>.^>>^v<<^>vv<^v>><.<v^v^<<><v><^^.^^^>^.><^>v^v<<<<>>^>v>^v<^<>..v<.<v<><>v^>v^^v..<>^<><>^v<<v<<><<.v>...>^^v>.>v^.^>vv>^v<>v><<^.>^^..<<^<#
#><v^<^..>>v<v.<>vvv>v<v^>>>.v^<^v<>.>^<.<<^<>.<..>.^.>^^>.^.^^>v.v^>v<^>^v.<v^>v^^^vv><^>^>>>v><v<>>>..v.<^<.<<<>>><^<<v>>^<.>^^^<><^<.<^>^<v.^>vv>vv>#
#<><>v^..>v>^^^^<.v>v>..<>><^><<^v.v.<v^<v><><<<v>>>^^>>v<<>^^<^^^>v.<<>v^<v><v^<<v>>^v>>v><v^^>vv^<^v<^v^.><>vv>>>.>>v^<v^v>><^^v.^<v.><v^^<<<v^>>^v^>#
#>v><>><<^.>v^.v<<<v><^vv<.v^>v<.>vv>v>>^<^<<><>v>v<v..v<^<.vvv<^>^^v<^.>.^^^>^^v.^.>^>>>^><v<.v<^^^^.v.vv<<vv<.>v<^>v^<<vv^v><v>v^>>v.^.^<<.vv>^^^<^v<#
#<v^<>>^>>^..vv<^<<<v.v.^vv<.<^^<v^<.>^<.^.<<v^^^<^><>.>>>><^<>^>^v>><v^>v.<.^<v>^^>><><.>^v^>^<>^<^^.<^>^^^^^^vv<>vv^v^v>^v^<v<vv><<vv<^^^.>>^><<<.^>>#
#<.<v^.>>><vv^.<^^^>>>.><v<v>^<>>.^^vv>>^<<<^v><^^<v<>>^^^^<v^<>^^>><^>v^<<>>v<^.>vvvv>>^<.^>.v<^^<<v>>.vv.v^v<>>>><^v^>>>.v.^^v<<v>v^^>^v>^v<><.v><^v.#
#><<^v><<<.v<^^><^v<^v.<<<.^^.v>vvvv>^>><^^v<>.<>><<.v^>..^<>.><^>^>^v^^>v<<vv>^>vvv.>^^>^^<<>v>v^>^^^<^v>.v>^<><^<.v<^><<>^.^>>><<v^>v^v^v<^v>>^^^><^<#
#<^>v<>.>>^.v>^<v><>.v.^^v>^<..v.^>^>.v>>><vv^<>^^>v><>vv.<v<v^vv<.^vv<><v>>>^v><v^vvvvv.<vv>>^v<<.v>v^>v><<<^.<<<<>vv>^>>^<>^^<vvv^<vvvvvv><^^<<<>^^<>#
#>>.>>.^>..<^<^.<<v<><>..^^<..v<.><^^<v.v^v><>^vv<v<^v<^>.v<vvvv><<<>^>^v^>v<>><vv^v<>>>>>v<v<>^.>><v<v.>><v<v^^<v.<><.<>^^^^v<<^>>.><<.><.v^^..>>>.v>>#
#>v<v^^<^vvv.>^<>>v^v.vv^>v^vvvvv<>.v^.v<.><>^>>^<<v<^^v>v><^.>>^><>v<vv>v<<^>^>^.<v>vv<<>^^>^<<>v><v>.<<^.<>><<^<<.^<^<<<.^>.<.vv>v^v<^>vvv>^v<<<<v<<<#
#<^<>v^.^<><>^<>^>v<v.^v..v..vv^.<.^^>^>^><.vv>>.<^..^^^<^<.^^<^^v^<^.<<<<<v<^<<><v>^v.<<>.^>><^>^v>><<v<>^v^<<^>>v<<^.v<<^vv>>v>^.v^^^<><vv^^<<>.v.<><#
#..vv<v><^vv>.v<v<^v><vvv>.v>^v^>>vv^.^>v.v^^<<>^^<>^<^^>.<^v<v>^>^<v<<v<>v<^^^>v>><><<><.<<><^<v<<>v^^>>v><>^v^.v>^^v<^><><^v<^<vv.vvv><><<>v<<><>v<.>#
#>>.<^^>><<<^>v<^^>>^<<>><<.<^^^<^^^<^<v<^<<^><<v<v<^^>vv<<^v>.^<^^>><>^^^.>v>v^<^>>v><<^<^^^>v><<>^^v><>v..<.^^>..vv.<v>>>^<<v^<v^^v>>>>.>vv.>>^v>^v<.#
######################################################################################################################################################.#""".split()

# %%
# mapp="""#.######
# #>>.<^<#
# #.<..<<#
# #>v.><>#
# #<^v^^>#
# ######.#""".split()

# %%
height = len(mapp)
width = len(mapp[0])

starting_point = (0, mapp[0].find("."))
start_row = 0
start_col = mapp[0].find(".")
end_row = height - 1
end_col = mapp[-1].find(".")


transforms = {
    None: lambda row, col: (row, col),
    "^": lambda row, col: (row - 1, col),
    "v": lambda row, col: (row + 1, col),
    "<": lambda row, col: (row, col - 1),
    ">": lambda row, col: (row, col + 1),
}

wrapmap = {
    "^": lambda row, col: (height - 2, col),
    "v": lambda row, col: (1, col),
    "<": lambda row, col: (row, width - 2),
    ">": lambda row, col: (row, 1),
}


def transform(row, col, direction):
    return transforms[direction](row, col)


def off_limits(row, column):
    if (row, column) == (start_row, start_col):
        return False
    if (row, column) == (end_row, end_col):
        return False
    return row <= 0 or row >= height - 1 or column <= 0 or column >= width - 1
        

def get_next_position(mover, wrap=True):
    (row, col, direction) = mover
    row, col = transform(row, col, direction or direction)
    if off_limits(row, col) and wrap:
        row, col = wrapmap[direction](row, col)
    return row, col

def get_next_position_with_direction(mover, wrap=True):
    row, col = get_next_position(mover, wrap)
    return (row, col, mover[2])

        
    
def move_to_next_position(mover, wrap=True):
    (row, col, direction) = mover
    row, col = get_next_position((row, col, direction, wrap))
    return (row, col, direction)




elements = []
for row in range(height):
    for col in range(width):
        val = mapp[row][col]
        if val not in {".", "#"}:
            elements.append((row, col, val))
        


def print_points(elements, elf_row, elf_col):
    points = {(b[0], b[1]): b for b in elements}
    for row in range(height):
        for col in range(width):
            if (row, col) in points:
                (_, _, direction) = points[(row, col)]
                print(direction, end="")
            elif (row, col) == (elf_row, elf_col):
                print("%", end="")
            elif row == 0 or row == height - 1 or col == 0 or col == width - 1:
                print("#", end="")
            else:
                print(".", end="")
        print("")

def get_valid_moves(elements, elf_row, elf_col):
    new_blizzard_points = set(get_next_position(elt) for elt in elements)
    moves = [transform(elf_row, elf_col, d) for d in "^v<>"] + [(elf_row, elf_col)]
    valid_moves = [move for move in moves if move not in new_blizzard_points and not off_limits(move[0], move[1])]
    return valid_moves




def run(row, col, elements, end):
    hashmap = {}
    things_to_try = [(row, col, elements, 1)]
    hashmap = {}

    while things_to_try:  
        (row, col, elements, depth) = things_to_try.pop(0)

        key = hash("{}{}{}".format(row, col, elements))
        if key in hashmap and hashmap[key] >= depth:
            continue
        valid_moves = get_valid_moves(elements, row, col)

        hashmap[key] = depth

        if not valid_moves:
            continue

        new_positions = [get_next_position_with_direction(elt) for elt in elements]
        if end in valid_moves:
            print("Found: {}, {} ({} moves)".format(end_row, end_col, depth))
            return (depth, new_positions)
            break

        for (row, col) in valid_moves:
            things_to_try.append((row, col, new_positions, depth + 1))


depth1, new_positions = run(start_row, start_col, elements, (end_row, end_col))
depth2, new_positions = run(end_row, end_col, new_positions, (start_row, start_col))
depth3, new_positions = run(start_row, start_col, new_positions, (end_row, end_col))
print(depth1+depth2+depth3)
